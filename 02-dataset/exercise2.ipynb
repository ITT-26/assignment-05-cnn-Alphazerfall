# %%
import cv2
import json
from matplotlib import pyplot as plt
import numpy as np
import os
import random

# import a lot of things from keras:
# sequential model
from keras.models import Sequential

# layers
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, RandomFlip, RandomRotation, RandomContrast, RandomBrightness

# loss function
from keras.metrics import categorical_crossentropy

# callback functions
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# convert data to categorial vector representation
from keras.utils import to_categorical

# nice progress bar for loading data
from tqdm.notebook import tqdm

# helper function for train/test split
from sklearn.model_selection import train_test_split

# import confusion matrix helper function
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# import pre-trained model
from keras.applications.vgg16 import VGG16

# include only those gestures
CONDITIONS = ['dislike','like','peace', 'rock', 'stop']

# image size
IMG_SIZE = 64
SIZE = (IMG_SIZE, IMG_SIZE)

# number of color channels we want to use
# set to 1 to convert to grayscale
# set to 3 to use color images
COLOR_CHANNELS = 3

# %% [markdown]
# ## helper function to load and parse annotations

# %%
annotations = dict()

for condition in CONDITIONS:
    with open(f'../data/_annotations/{condition}.json') as f:
        annotations[condition] = json.load(f)

# %% [markdown]
# ## helper function to pre-process images (color channel conversion and resizing)

# %%
def preprocess_image(img):
    if COLOR_CHANNELS == 1:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_resized = cv2.resize(img, SIZE)
    return img_resized

# %% [markdown]
# ## load images and annotations

# %%
images = []
labels = []
label_names = []

for condition in CONDITIONS:
    for filename in tqdm(os.listdir(f'../data/{condition}')):
        UID = filename.split('.')[0]
        img = cv2.imread(f'../data/{condition}/{filename}')
        
        try:
            annotation = annotations[condition][UID]
        except Exception as e:
            print(e)
            continue
        
        for i, bbox in enumerate(annotation['bboxes']):
            x1 = int(bbox[0] * img.shape[1])
            y1 = int(bbox[1] * img.shape[0])
            w = int(bbox[2] * img.shape[1])
            h = int(bbox[3] * img.shape[0])
            x2 = x1 + w
            y2 = y1 + h
            
            crop = img[y1:y2, x1:x2]
            preprocessed = preprocess_image(crop)
            
            label = annotation['labels'][i]
            if label == "no_gesture":
                continue
            if label not in label_names:
                label_names.append(label)
            
            label_index = label_names.index(label)
            
            images.append(preprocessed)
            labels.append(label_index)
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
#   0%|          | 0/250 [00:00<?, ?it/s]
#   0%|          | 0/250 [00:00<?, ?it/s]
#   0%|          | 0/250 [00:00<?, ?it/s]
#   0%|          | 0/250 [00:00<?, ?it/s]

# %% [markdown]
# ## let's have a look at one of the images

# %%
plt.imshow(random.sample(images, 1)[0])

# %% [markdown]
# ## split data set into train and test
#
# x is for the actual data, y is for the label (this is convention)

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 1000
# 250
# 1000
# 250

# %% [markdown]
# ## transform data sets into a format compatible with our neural network
#
# image data has to be a numpy array with following dimensions: [image_id, y_axis, x_axis, color_channels]
#
# furthermore, scale all values to a range of 0 to 1
#
# training data has to be converted to a categorial vector ("one hot"):
#
# [3] --> [0, 0, 0, 1, 0, ..., 0]

# %%
X_train = np.array(X_train).astype('float32')
X_train = X_train / 255.

X_test = np.array(X_test).astype('float32')
X_test = X_test / 255.

y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

train_label = y_train_one_hot
test_label = y_test_one_hot

X_train = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)
X_test = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)

print(X_train.shape, X_test.shape, train_label.shape, test_label.shape)
# Out:
# (1000, 64, 64, 3) (250, 64, 64, 3) (1000, 5) (250, 5)

# %%
# variables for hyperparameters
batch_size = 8
epochs = 50
num_classes = len(label_names)
activation = 'relu'
activation_conv = 'leaky_relu'  # LeakyReLU
layer_count = 2
num_neurons = 64

# define model structure
# with keras, we can use a model's add() function to add layers to the network one by one
model = Sequential()

# data augmentation (this can also be done beforehand - but don't augment the test dataset!)
model.add(RandomFlip('horizontal'))
model.add(RandomContrast(0.1))
#model.add(RandomBrightness(0.1))
#model.add(RandomRotation(0.2))

# first, we add some convolution layers followed by max pooling
model.add(Conv2D(64, kernel_size=(9, 9), activation=activation_conv, input_shape=(SIZE[0], SIZE[1], COLOR_CHANNELS), padding='same'))
model.add(MaxPooling2D(pool_size=(4, 4), padding='same'))

model.add(Conv2D(32, (5, 5), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(3, 3), padding='same'))

model.add(Conv2D(32, (3, 3), activation=activation_conv, padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

# dropout layers can drop part of the data during each epoch - this prevents overfitting
model.add(Dropout(0.2))

# after the convolution layers, we have to flatten the data so it can be fed into fully connected layers
model.add(Flatten())

# add some fully connected layers ("Dense")
for i in range(layer_count - 1):
    model.add(Dense(num_neurons, activation=activation))

model.add(Dense(num_neurons, activation=activation))

# for classification, the last layer has to use the softmax activation function, which gives us probabilities for each category
model.add(Dense(num_classes, activation='softmax'))

# specify loss function, optimizer and evaluation metrics
# for classification, categorial crossentropy is used as a loss function
# use the adam optimizer unless you have a good reason not to
model.compile(loss=categorical_crossentropy, optimizer="adam", metrics=['accuracy'])

# define callback functions that react to the model's behavior during training
# in this example, we reduce the learning rate once we get stuck and early stopping
# to cancel the training if there are no improvements for a certain amount of epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=0.0001)
stop_early = EarlyStopping(monitor='val_loss', patience=3)
# Out:
# c:\Users\Felix\Documents\Uni\ITT\assignment-05-cnn-Alphazerfall\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## now, we can train the model using the fit() function
# ## this will take a while

# %%
history = model.fit(
    X_train,
    train_label,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, test_label),
    callbacks=[reduce_lr, stop_early]
)
# Out:
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.2020 - loss: 1.6240 - val_accuracy: 0.3320 - val_loss: 1.5993 - learning_rate: 0.0010
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.2230 - loss: 1.6087 - val_accuracy: 0.2640 - val_loss: 1.6025 - learning_rate: 0.0010
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.3060 - loss: 1.5522 - val_accuracy: 0.4280 - val_loss: 1.3966 - learning_rate: 0.0010
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.4070 - loss: 1.3808 - val_accuracy: 0.4440 - val_loss: 1.2493 - learning_rate: 0.0010
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5590 - loss: 1.1062 - val_accuracy: 0.7280 - val_loss: 0.8396 - learning_rate: 0.0010
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.6560 - loss: 0.8528 - val_accuracy: 0.7960 - val_loss: 0.5193 - learning_rate: 0.0010
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7410 - loss: 0.6620 - val_accuracy: 0.8160 - val_loss: 0.5160 - learning_rate: 0.0010
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7850 - loss: 0.5577 - val_accuracy: 0.8320 - val_loss: 0.4427 - learning_rate: 0.0010
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8140 - loss: 0.4670 - val_accuracy: 0.8280 - val_loss: 0.4496 - learning_rate: 0.0010
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.8420 - loss: 0.3769 - val_accuracy: 0.8880 - val_loss: 0.2983 - learning_rate: 0.0010
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8770 - loss: 0.3487 - val_accuracy: 0.8760 - val_loss: 0.3810 - learning_rate: 0.0010
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8940 - loss: 0.3103 - val_accuracy: 0.9200 - val_loss: 0.2575 - learning_rate: 0.0010
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.9040 - loss: 0.2451 - val_accuracy: 0.8920 - val_loss: 0.2746 - learning_rate: 0.0010
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.9110 - loss: 0.2567 - val_accuracy: 0.9040 - val_loss: 0.2504 - learning_rate: 0.0010
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9330 - loss: 0.2197 - val_accuracy: 0.9400 - val_loss: 0.2272 - learning_rate: 0.0010
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9410 - loss: 0.1789 - val_accuracy: 0.9440 - val_loss: 0.1808 - learning_rate: 0.0010
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9360 - loss: 0.1638 - val_accuracy: 0.9000 - val_loss: 0.3090 - learning_rate: 0.0010
# Epoch 18/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9420 - loss: 0.1630 - val_accuracy: 0.9320 - val_loss: 0.2292 - learning_rate: 0.0010
# Epoch 19/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.9690 - loss: 0.0943 - val_accuracy: 0.9360 - val_loss: 0.1646 - learning_rate: 2.0000e-04
# Epoch 20/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9730 - loss: 0.0676 - val_accuracy: 0.9520 - val_loss: 0.1537 - learning_rate: 2.0000e-04
# Epoch 21/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9830 - loss: 0.0558 - val_accuracy: 0.9440 - val_loss: 0.1410 - learning_rate: 2.0000e-04
# Epoch 22/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9830 - loss: 0.0568 - val_accuracy: 0.9400 - val_loss: 0.1648 - learning_rate: 2.0000e-04
# Epoch 23/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.9770 - loss: 0.0696 - val_accuracy: 0.9480 - val_loss: 0.1523 - learning_rate: 2.0000e-04
# Epoch 24/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.9860 - loss: 0.0427 - val_accuracy: 0.9480 - val_loss: 0.1511 - learning_rate: 1.0000e-04

# %%
# let's have a look at our model
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip_1 (RandomFlip)      │ (8, 64, 64, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_contrast_1               │ (8, 64, 64, 3)         │             0 │
# │ (RandomContrast)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (8, 64, 64, 64)        │        15,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (8, 16, 16, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (8, 16, 16, 32)        │        51,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (8, 6, 6, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (8, 6, 6, 32)          │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (8, 3, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (8, 288)               │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (8, 64)                │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (8, 64)                │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (8, 5)                 │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 297,233 (1.13 MB)
#  Trainable params: 99,077 (387.02 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 198,156 (774.05 KB)

# %% [markdown]
# ## Plot accuracy and loss of the training process

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

# %% [markdown]
# ## saving the model
#
# the function will create a directory for your model and save structure and weights in there
#
# sometimes you will see the .h5 format being used - even though this is a bit faster and needs less space, it comes with its limitations and isn't used that much any more

# %%
model.save('gesture_recognition.keras')

# and this is how you load the model
# model = keras.models.load_model("gesture_recognition")

# %% [markdown]
# ## visualize classification results with a confusion matrix

# %% [markdown]
# ## Transfer Learning
#
# let's use a pre-trained model (VGG16) for our prediction
#
# note that VGG16 needs three color channels

# %%
batch_size = 8
epochs = 50
num_classes = len(label_names)
activation = 'relu'
activation_conv = 'LeakyReLU'  # LeakyReLU
layer_count = 2
num_neurons = 256

# load a VGG16 model trained on the imagenet dataset
# include_top=False -> do not include the output layer
# input_tensor -> tells the model about the dimensions of our images (VGG16 needs three color channels)
# pooling -> which type of pooling to use between convolutions; max or avg seem to be the best
VGG = VGG16(weights='imagenet', include_top=False, input_tensor=Input(shape=(IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)), pooling='max')

# we want to use the VGG's original weights -> make those layers untrainable
for layer in VGG.layers:
    layer.trainable = False

# build a new model and add the VGG layers
model_vgg = Sequential()
model_vgg.add(VGG)

# append dense layers at the end
for i in range(layer_count - 1):
    model_vgg.add(Dense(num_neurons, activation=activation))
model_vgg.add(Dropout(0.2))

model_vgg.add(Dense(num_neurons, activation=activation))

# classifier
model_vgg.add(Dense(num_classes, activation='softmax'))

model_vgg.compile(loss=categorical_crossentropy, optimizer="adam", metrics=['accuracy'])

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2, min_lr=0.0001)
stop_early = EarlyStopping(monitor='val_loss', patience=3)

# %%
history_vgg = model_vgg.fit(
    X_train,
    train_label,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, test_label),
    callbacks=[reduce_lr, stop_early]
)
# Out:
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 19s 141ms/step - accuracy: 0.5730 - loss: 1.0514 - val_accuracy: 0.8360 - val_loss: 0.5106 - learning_rate: 0.0010
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 29s 235ms/step - accuracy: 0.7900 - loss: 0.5456 - val_accuracy: 0.8600 - val_loss: 0.4096 - learning_rate: 0.0010
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - accuracy: 0.8580 - loss: 0.3951 - val_accuracy: 0.8720 - val_loss: 0.3434 - learning_rate: 0.0010
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 19s 150ms/step - accuracy: 0.8670 - loss: 0.3477 - val_accuracy: 0.8440 - val_loss: 0.4153 - learning_rate: 0.0010
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 19s 154ms/step - accuracy: 0.9120 - loss: 0.2508 - val_accuracy: 0.8960 - val_loss: 0.3135 - learning_rate: 0.0010
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - accuracy: 0.9250 - loss: 0.2056 - val_accuracy: 0.8880 - val_loss: 0.3494 - learning_rate: 0.0010
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - accuracy: 0.9150 - loss: 0.2173 - val_accuracy: 0.8440 - val_loss: 0.3861 - learning_rate: 0.0010
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 17s 134ms/step - accuracy: 0.9660 - loss: 0.1087 - val_accuracy: 0.8960 - val_loss: 0.3053 - learning_rate: 3.0000e-04
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.9800 - loss: 0.0796 - val_accuracy: 0.9000 - val_loss: 0.2924 - learning_rate: 3.0000e-04
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.9800 - loss: 0.0671 - val_accuracy: 0.8920 - val_loss: 0.3104 - learning_rate: 3.0000e-04
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 16s 130ms/step - accuracy: 0.9800 - loss: 0.0650 - val_accuracy: 0.8760 - val_loss: 0.3197 - learning_rate: 3.0000e-04
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 162ms/step - accuracy: 0.9910 - loss: 0.0486 - val_accuracy: 0.8960 - val_loss: 0.2869 - learning_rate: 1.0000e-04
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - accuracy: 0.9880 - loss: 0.0499 - val_accuracy: 0.9000 - val_loss: 0.2858 - learning_rate: 1.0000e-04
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - accuracy: 0.9920 - loss: 0.0435 - val_accuracy: 0.9000 - val_loss: 0.2800 - learning_rate: 1.0000e-04
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 145ms/step - accuracy: 0.9950 - loss: 0.0384 - val_accuracy: 0.9080 - val_loss: 0.2910 - learning_rate: 1.0000e-04
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 24s 195ms/step - accuracy: 0.9900 - loss: 0.0379 - val_accuracy: 0.8920 - val_loss: 0.2944 - learning_rate: 1.0000e-04
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 19s 150ms/step - accuracy: 0.9930 - loss: 0.0388 - val_accuracy: 0.8960 - val_loss: 0.3012 - learning_rate: 1.0000e-04

# %%
model_vgg.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 512)            │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,309,905 (58.40 MB)
#  Trainable params: 198,405 (775.02 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)
#  Optimizer params: 396,812 (1.51 MB)

# %%
model_vgg.save('gesture_recognition_vgg.keras')

# %%
loss = history_vgg.history['loss']
val_loss = history_vgg.history['val_loss']
accuracy = history_vgg.history['accuracy']
val_accuracy = history_vgg.history['val_accuracy']

fig = plt.figure(figsize=(15, 7))
ax = plt.gca()

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy (Line), Loss (Dashes)')

ax.axhline(1, color='gray')

plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.plot(loss, '--', color='blue', alpha=0.5)
plt.plot(val_loss, '--', color='orange', alpha=0.5)

# %%
y_pred_own = np.argmax(model.predict(X_test), axis=1)
y_pred_vgg = np.argmax(model_vgg.predict(X_test), axis=1)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

ConfusionMatrixDisplay(
    confusion_matrix(y_test, y_pred_own),
    display_labels=label_names
).plot(ax=ax1, colorbar=False)
ax1.set_title("Test set — Baseline CNN")
ax1.tick_params(axis='x', rotation=45)

ConfusionMatrixDisplay(
    confusion_matrix(y_test, y_pred_vgg),
    display_labels=label_names
).plot(ax=ax2, colorbar=False)
ax2.set_title("Test set — VGG16")
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 537ms/step

# %% [markdown]
# ## Evaluate the images I recorded myself

# %%
with open('annot-felix.json') as f:
    user_annotations = json.load(f)

user_images = []
user_true_labels = []

for condition in CONDITIONS:
    folder = f'data_felix/{condition}'
    if not os.path.exists(folder):
        continue
    for filename in os.listdir(folder):
        uid = os.path.splitext(filename)[0]
        if uid not in user_annotations:
            print(f'No annotation for {filename}, skipping')
            continue
        annotation = user_annotations[uid]
        img = cv2.imread(f'{folder}/{filename}')
        if img is None:
            print(f'Could not read {filename}, skipping')
            continue
        for i, bbox in enumerate(annotation['bboxes']):
            x1 = int(bbox[0] * img.shape[1])
            y1 = int(bbox[1] * img.shape[0])
            w  = int(bbox[2] * img.shape[1])
            h  = int(bbox[3] * img.shape[0])
            crop = img[y1:y1+h, x1:x1+w]
            preprocessed = preprocess_image(crop)
            label = annotation['labels'][i]
            if label == 'no_gesture':
                continue
            if label not in label_names:
                print(f'Unknown label "{label}" — not in training set, skipping')
                continue
            user_images.append(preprocessed)
            user_true_labels.append(label_names.index(label))

X_user = np.array(user_images).astype('float32') / 255.
X_user = X_user.reshape(-1, IMG_SIZE, IMG_SIZE, COLOR_CHANNELS)

# %%
y_pred_vgg = np.argmax(model_vgg.predict(X_user), axis=1)
y_pred_own = np.argmax(model.predict(X_user), axis=1)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

ConfusionMatrixDisplay(
    confusion_matrix(user_true_labels, y_pred_own),
    display_labels=label_names
).plot(ax=ax1, colorbar=False)
ax1.set_title("Own images — Baseline CNN")
ax1.tick_params(axis='x', rotation=45)

ConfusionMatrixDisplay(
    confusion_matrix(user_true_labels, y_pred_vgg),
    display_labels=label_names
).plot(ax=ax2, colorbar=False)
ax2.set_title("Own images — VGG16")
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('conf-matrix.png', dpi=150)
plt.show()
print('Saved conf-matrix.png')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Saved conf-matrix.png
